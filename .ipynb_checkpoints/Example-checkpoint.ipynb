# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import pandas as pd
import time
from functions import plots
from functions import finite_volumes as fv
from functions import finite_volumes_split as fvs
from functions import finite_volumes_par as fvp
from functions import neural_network as nn
import mnist

# %% [markdown]
# # IMAGE IMPAINTING WITH FLUID DYNAMICS

# %% [markdown]
# Image inpainting aims to remove damage from an image. There are various techniques for image inpainting, and here we focus on solving a fluid-type PDE denoted as the Cahn-Hilliard equation.
#
# The three take-home messages from this notebook are that:
#
# 1. Image inpainting can be solved with efficient and parallelizable finite-volume schemes
# 2. The classification accuracy of neural networks is affected by the presence of damage
# 3. The application of image inpainting in damaged images improves their classification accuracy

# %% [markdown]
# As an example we take the MNIST dataset, which consists of binary images of handwritten digits:

# %%
test_images = mnist.test_images()
test_images = test_images.reshape((-1,784))
test_images = (test_images / 255) *2-1
example = test_images[0,:]
plots.plot_image(example)

# %% [markdown]
# The MNIST dataset is corrupted by adding different types of damage to it:

# %%
test_images = mnist.test_images()
test_images = test_images.reshape((-1,784))
test_images = (test_images / 255) *2-1
example = test_images[0,:]

intensity = 0.5

damage = np.random.choice(np.arange(example.size), replace=False, size=int(example.size * intensity))
damaged_example = example.copy()
damaged_example[damage] = 0
plots.plot_image(damaged_example)

# %% [markdown]
# ## Finite volumes for image inpainting

# %% [markdown]
# With image inpainting we aim to recover the original image. There are various methods to conduct image inpainting, and here I solve a modified Cahn-Hilliard equation via parallelized finite-volume schemes:
#
#
# $$
# \frac{\partial \phi (x,t)}{\partial t}= -\nabla^{2} \left(\epsilon^2 \nabla^{2} \phi -  H'(\phi) \right) + \lambda(x)\left(\phi (x,t=0) - \phi\right)
# $$
#
# As a baseline let's solve this equation with a simple finite-volume scheme:

# %%
start = time.time()
restored_example = fv.temporal_loop(damaged_example, damage)
print("Total time: {:.2f}".format(time.time()-start))
plots.plot_image(restored_example)
# Out:
# --------------------
# Time:  0.0
# ['L1 norm of the difference between the new and old state: ', 298.4817377018757]
# --------------------
# Time:  0.1
# ['L1 norm of the difference between the new and old state: ', 67.99865963177484]
# --------------------
# Time:  0.2
# ['L1 norm of the difference between the new and old state: ', 27.966502047423766]
# --------------------
# Time:  0.30000000000000004
# ['L1 norm of the difference between the new and old state: ', 12.04641118819493]
# --------------------
# Time:  0.4
# ['L1 norm of the difference between the new and old state: ', 6.530433844349446]
# --------------------
# Time:  0.5
# ['L1 norm of the difference between the new and old state: ', 3.6413348438554616]
# --------------------
# Time:  0.6
# ['L1 norm of the difference between the new and old state: ', 2.309113937971872]
# --------------------
# Time:  0.7
# ['L1 norm of the difference between the new and old state: ', 1.523109077801041]
# --------------------
# ...

# %% [markdown]
# Let's compare the restored image with respect to the original image:

# %%
plots.plot_3images(example, damaged_example, restored_example)

# %% [markdown]
# The computational cost of finite-volume scheme can be reduced by:
#
# 1. Applying a dimensional-splitting technique and solving row by row and column by column
# 2. Parallelizing the code and solving rows/columns simultaneously
#
# The simple finite-volume scheme has taken 40s to run. Let's compare it with the dimensional-splitting code:fully parallelized code:

# %%
start = time.time()
restored_example = fvs.temporal_loop_split(damaged_example, damage)
print("Total time: {:.2f}".format(time.time()-start))
plots.plot_image(restored_example)
# Out:
# --------------------
# Time:  0.0
# ['L1 norm of the difference between the new and old state: ', 273.25439616200794]
# --------------------
# Time:  0.1
# ['L1 norm of the difference between the new and old state: ', 51.59688638407632]
# --------------------
# Time:  0.2
# ['L1 norm of the difference between the new and old state: ', 16.846276108291388]
# --------------------
# Time:  0.30000000000000004
# ['L1 norm of the difference between the new and old state: ', 7.237545558618694]
# --------------------
# Time:  0.4
# ['L1 norm of the difference between the new and old state: ', 3.6274181671245933]
# --------------------
# Time:  0.5
# ['L1 norm of the difference between the new and old state: ', 1.9907934783073489]
# --------------------
# Time:  0.6
# ['L1 norm of the difference between the new and old state: ', 1.1661482453230363]
# --------------------
# Time:  0.7
# ['L1 norm of the difference between the new and old state: ', 0.7201841187781879]
# --------------------
# ...

# %% [markdown]
# By dimensionally splitting the code we have reduced the computational time from 40s to 8s!
#
# Parallelizing the code does not reduce that time since MNIST images are only 28x28. However, for high-dimensional images it has a clear benefit. Let's run the parallel code:

# %%
num_proc = 8
start = time.time()
restored_example = fvp.temporal_loop_par(damaged_example, damage, num_proc)
print("Total time: {:.2f}".format(time.time()-start))
plots.plot_image(restored_example)
# Out:
# --------------------
# Time:  0.0
# ['L1 norm of the difference between the new and old state: ', 273.1053039896175]
# --------------------
# Time:  0.1
# ['L1 norm of the difference between the new and old state: ', 51.25390411756689]
# --------------------
# Time:  0.2
# ['L1 norm of the difference between the new and old state: ', 17.016682785097963]
# --------------------
# Time:  0.30000000000000004
# ['L1 norm of the difference between the new and old state: ', 7.365719446330556]
# --------------------
# Time:  0.4
# ['L1 norm of the difference between the new and old state: ', 3.704307607055964]
# --------------------
# Time:  0.5
# ['L1 norm of the difference between the new and old state: ', 2.0256247702061234]
# --------------------
# Time:  0.6
# ['L1 norm of the difference between the new and old state: ', 1.18536791821615]
# --------------------
# Time:  0.7
# ['L1 norm of the difference between the new and old state: ', 0.7315914125374572]
# --------------------
# ...

# %% [markdown]
# The parallel code takes 15 seconds, which is a bit higher than the non-parallel one.

# %% [markdown]
# ## Neural network for classification

# %% [markdown]
# ![title](images/NN.png)

# %%
train_images = mnist.train_images()
train_labels = mnist.train_labels()
train_images = (train_images / 255) *2-1
train_images = train_images.reshape((-1,784))

model, history = nn.training(train_images, train_labels)
plots.loss_acc_plots(history)

test_labels = mnist.test_labels()
test_loss, test_accuracy = model.evaluate(test_images, to_categorical(test_labels), verbose=2)
# Out:
# Train on 60000 samples
# Epoch 1/8
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.3422 - accuracy: 0.8965
# Epoch 2/8
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1837 - accuracy: 0.9443
# Epoch 3/8
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1435 - accuracy: 0.9559
# Epoch 4/8
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.1213 - accuracy: 0.9618
# Epoch 5/8
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.1072 - accuracy: 0.9661
# Epoch 6/8
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.0955 - accuracy: 0.9701
# Epoch 7/8
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0861 - accuracy: 0.9724
# Epoch 8/8
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.0825 - accuracy: 0.9730
# 10000/10000 - 0s - loss: 0.0984 - accuracy: 0.9691

# %% [markdown]
# The accuracy for the test dataset is quite high: 96%. This accuracy drops as we include damage in the test images. For instance, with an intensity of 80% the accuracy is 55%. Can we recover the accuracy by firstly applying image inpainting?

# %% [markdown]
# ## Image inpainting prior to classifying damaged images

# %% [markdown]
# Let's select a group of 5 images to add damage:

# %%
n_images = 5
indices_images = range(n_images)
examples = test_images[indices_images,:].copy()

intensity = 0.80
damages = np.zeros((len(indices_images), int(examples.shape[1] * intensity)), dtype=int)
damaged_examples = examples.copy()
for i in indices_images:
    damages[i, :] = np.random.choice(np.arange(examples.shape[1]), replace=False, size=int(examples.shape[1] * intensity))
    damaged_examples[i, damages[i, :]] = 0

plots.plot_image(damaged_examples[1,:])

# %% [markdown]
# We proceed to restore those 5 images:

# %%
restored_examples = np.zeros(examples.shape)
for i in range(n_images):
    restored_examples[i,:] = fvs.temporal_loop_split(examples[i, :], damages[i, :])

plots.plot_3images(examples[1,:], damaged_examples[1,:], restored_examples[1,:])
# Out:
# --------------------
# Time:  0.0
# ['L1 norm of the difference between the new and old state: ', 50.63490708181547]
# --------------------
# Time:  0.1
# ['L1 norm of the difference between the new and old state: ', 18.357831647320417]
# --------------------
# Time:  0.2
# ['L1 norm of the difference between the new and old state: ', 10.658271562947341]
# --------------------
# Time:  0.30000000000000004
# ['L1 norm of the difference between the new and old state: ', 7.719388689785324]
# --------------------
# Time:  0.4
# ['L1 norm of the difference between the new and old state: ', 6.156186692905662]
# --------------------
# Time:  0.5
# ['L1 norm of the difference between the new and old state: ', 5.208600018227907]
# --------------------
# Time:  0.6
# ['L1 norm of the difference between the new and old state: ', 4.523172341924502]
# --------------------
# Time:  0.7
# ['L1 norm of the difference between the new and old state: ', 3.990295081634907]
# --------------------
# ...

# %% [markdown]
# We can now compare the ground truth with the predicted labels for the damaged and restore images:

# %%
predictions_damaged = np.argmax(model.predict(damaged_examples), axis=1)  
predictions_restored = np.argmax(model.predict(restored_examples), axis=1)    

print("Ground truth: ", test_labels[indices_images])
print("Damaged images: ", predictions_damaged)
print("Restored restored: ", predictions_restored)
# Out:
# Ground truth:  [7 2 1 0 4]
# Damaged images:  [7 2 3 0 4]
# Restored restored:  [7 2 1 0 4]

# %% [markdown]
# ## Final remarks
